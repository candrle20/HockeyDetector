# %%
# !pip install tensorflow==2.13.0
import os
import cv2
import tensorflow as tf
import google.protobuf
from tensorflow.python.keras.utils.data_utils import get_file

# %%
#Install Protoc and TF OBJ Detection API
# %cd /content
if not os.path.exists('/content/drive/MyDrive/tf_training/models'):
  # !git clone https://github.com/tensorflow/models

# %cd /content/drive/MyDrive/tf_training/models/research
# !protoc object_detection/protos/*.proto --python_out=.

# %cp object_detection/packages/tf2/setup.py .
# !python -m pip install .
# Out:
# /content
# /content/drive/MyDrive/tf_training/models/research
# Processing /content/drive/MyDrive/tf_training/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tensorflow-2.15.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
# ...
#   Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# ...
#   Using cached tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
# ...
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697356 sha256=f3d89913749954364dc6a6b45f98bbc9c137d782d9bd279b6037ee5e13c634b1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06g0w0r0/wheels/32/eb/37/0f442d1a61606acacc8fb32a927fab63956040142a8fd94339
# Successfully built object-detection
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/tf_training

# %%
model_path = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d1_coco17_tpu-32.tar.gz'
model_file = os.path.basename(model_path)
model_name =  model_file.split('.')[0]
output_dir = 'workspace/pretrained_model'
get_file(model_file, model_path, cache_dir=output_dir, extract=True)
# Out:
# ...
# 51847168/51839363 [==============================] - 0s 0us/step
# 'workspace/pretrained_model/datasets/efficientdet_d1_coco17_tpu-32.tar.gz'

# %%
##Run to Test Proper Installation

# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-12-20 19:36:55.893231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-12-20 19:36:58.949942: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W1220 19:36:59.153151 133017014915072 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...

# %%
#Restore Checkpoint
checkpoint_path =
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(checkpoint_path, 'ckpt-0')).expect_partial()
# Out:
#   File "<ipython-input-16-9e2306d404d0>", line 1
#     http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d1_coco17_tpu-32.tar.gz
#                                                                                                      ^
# SyntaxError: invalid decimal literal

# %%
# !python workspace/model_main_tf2.py \
  --pipeline_config_path='workspace/tuned_model/efficientdet_d1_coco17_tpu-32/pipeline.config' \
  --model_dir='tf_training/workspace/tuned_model' \
  --checkpoint_every_n=500 \
  --num_workers=2 \
  --alsologtostderr
# Out:
# 2023-12-20 20:22:15.276210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /content/drive/MyDrive/tf_training/workspace/model_main_tf2.py:100: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# W1220 20:22:18.084450 132848786817024 deprecation.py:364] From /content/drive/MyDrive/tf_training/workspace/model_main_tf2.py:100: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# Instructions for updating:
# use distribute.MultiWorkerMirroredStrategy instead
# ...
